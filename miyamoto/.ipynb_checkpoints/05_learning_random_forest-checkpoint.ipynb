# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from datetime import datetime as dt
import pickle

# %%
df=pd.read_csv('../dataset/train_data1.csv')

# %%
df=df.drop(['air_store_id','reserve_visitors','diff_day'],axis=1)

# %%
print(df.shape)
df.head()
# Out:
# (42193, 34)
#                      store_id_date  visitors  year  month  day  season  \
# 0  air_00a91d42b08b08d9_2016-01-14       NaN     0      1   14       0
# 1  air_00a91d42b08b08d9_2016-01-15       NaN     0      1   15       0
# 2  air_00a91d42b08b08d9_2016-01-16       NaN     0      1   16       0
# 3  air_00a91d42b08b08d9_2016-01-22       NaN     0      1   22       0
# 4  air_00a91d42b08b08d9_2016-01-29       NaN     0      1   29       0
#
#    day_of_week  working_day  holiday_flg  air_genre_name      ...        \
# 0            4            0            0               6      ...
# 1            5            0            0               6      ...
# 2            6            1            0               6      ...
# 3            5            0            0               6      ...
# 4            5            0            0               6      ...
#
#    max_working_day  max_holiday_flg  max_season  median_year  median_month  \
# 0             54.0             99.0        99.0         29.0          36.0
# 1             54.0             99.0        99.0         29.0          36.0
# 2             99.0             99.0        99.0         29.0          36.0
# 3             54.0             99.0        99.0         29.0          36.0
# 4             54.0             99.0        99.0         29.0          36.0
#
#    median_day  median_day_of_week  median_working_day  median_holiday_flg  \
# 0        29.0                34.0                33.0                29.0
# 1        52.0                38.0                33.0                29.0
# 2        20.0                11.0                11.0                29.0
# 3        37.0                38.0                33.0                29.0
# 4        52.0                38.0                33.0                29.0
#
#    median_season
# 0           33.0
# 1           33.0
# 2           33.0
# 3           33.0
# 4           33.0
#
# [5 rows x 34 columns]

# %%
df1=df.dropna()
df1.set_index('store_id_date',drop=True,inplace=True)

# %%
print(df1.shape)
df1.head()
# Out:
# (35698, 33)
#                                  visitors  year  month  day  season  \
# store_id_date
# air_00a91d42b08b08d9_2016-07-01      35.0     0      7    1       2
# air_00a91d42b08b08d9_2016-07-06      29.0     0      7    6       2
# air_00a91d42b08b08d9_2016-07-08      42.0     0      7    8       2
# air_00a91d42b08b08d9_2016-07-09      11.0     0      7    9       2
# air_00a91d42b08b08d9_2016-07-13      36.0     0      7   13       2
#
#                                  day_of_week  working_day  holiday_flg  \
# store_id_date
# air_00a91d42b08b08d9_2016-07-01            5            0            0
# air_00a91d42b08b08d9_2016-07-06            3            0            0
# air_00a91d42b08b08d9_2016-07-08            5            0            0
# air_00a91d42b08b08d9_2016-07-09            6            1            0
# air_00a91d42b08b08d9_2016-07-13            3            0            0
#
#                                  air_genre_name  air_area_name      ...        \
# store_id_date                                                       ...
# air_00a91d42b08b08d9_2016-07-01               6             44      ...
# air_00a91d42b08b08d9_2016-07-06               6             44      ...
# air_00a91d42b08b08d9_2016-07-08               6             44      ...
# air_00a91d42b08b08d9_2016-07-09               6             44      ...
# air_00a91d42b08b08d9_2016-07-13               6             44      ...
#
#                                  max_working_day  max_holiday_flg  max_season  \
# store_id_date
# air_00a91d42b08b08d9_2016-07-01             54.0             99.0        53.0
# air_00a91d42b08b08d9_2016-07-06             54.0             99.0        53.0
# air_00a91d42b08b08d9_2016-07-08             54.0             99.0        53.0
# air_00a91d42b08b08d9_2016-07-09             99.0             99.0        53.0
# air_00a91d42b08b08d9_2016-07-13             54.0             99.0        53.0
#
#                                  median_year  median_month  median_day  \
# store_id_date
# air_00a91d42b08b08d9_2016-07-01         29.0          32.0        26.0
# air_00a91d42b08b08d9_2016-07-06         29.0          32.0        32.5
# air_00a91d42b08b08d9_2016-07-08         29.0          32.0        35.0
# air_00a91d42b08b08d9_2016-07-09         29.0          32.0        26.0
# air_00a91d42b08b08d9_2016-07-13         29.0          32.0        36.0
#
#                                  median_day_of_week  median_working_day  \
# store_id_date
# air_00a91d42b08b08d9_2016-07-01                38.0                33.0
# air_00a91d42b08b08d9_2016-07-06                28.0                33.0
# air_00a91d42b08b08d9_2016-07-08                38.0                33.0
# air_00a91d42b08b08d9_2016-07-09                11.0                11.0
# air_00a91d42b08b08d9_2016-07-13                28.0                33.0
#
#                                  median_holiday_flg  median_season
# store_id_date
# air_00a91d42b08b08d9_2016-07-01                29.0           34.5
# air_00a91d42b08b08d9_2016-07-06                29.0           34.5
# air_00a91d42b08b08d9_2016-07-08                29.0           34.5
# air_00a91d42b08b08d9_2016-07-09                29.0           34.5
# air_00a91d42b08b08d9_2016-07-13                29.0           34.5
#
# [5 rows x 33 columns]

# %%
X = df1.drop('visitors', axis=1).as_matrix()
y = df1['visitors']

#データをわける
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 666)

# %%
# Grid Search
params={'n_estimators':[300], 
                'max_depth':[12], #確定
                'criterion':['mse'],
                'random_state':[1],
                'n_jobs':[-1]
}

rf_model=RandomForestRegressor()
gs = GridSearchCV(rf_model,params)
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_jobs': [-1], 'random_state': [1], 'n_estimators': [300], 'max_depth': [12], 'criterion': ['mse']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
y_test_pred = gs.predict(X_test)
y_train_pred =gs.predict(X_train)
gs.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 12,
#  'n_estimators': 300,
#  'n_jobs': -1,
#  'random_state': 1}

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_test_pred))
print(mean_squared_error(y_train,y_train_pred))
# Out:
# 96.2366349807
# 52.9300754338

# %%
from sklearn.metrics import r2_score
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 0.842128545119
# 0.715421801421

# %%
u_lim=150
l_lim=0
plt.figure(figsize=(8, 8))
plt.plot([l_lim,u_lim], [l_lim,u_lim], c='k', alpha=0.6, label = 'diagonal line') # diagonal line
plt.scatter(y_train,y_train_pred,label='train')
plt.scatter(y_test,y_test_pred,label='test')
plt.xlim(l_lim,u_lim)
plt.ylim(l_lim,u_lim)
plt.xlabel('acutual', fontsize=16)
plt.ylabel('predicted', fontsize=16)
plt.legend()
plt.grid()
plt.show()

# %%
with open('rf.pickle', mode='wb') as f:
    pickle.dump(gs, f)

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(df1.corr())
plt.show()
